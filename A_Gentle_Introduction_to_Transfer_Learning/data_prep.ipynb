# %% [markdown]
# # Data preparation

# %%
import os
from utils import split_dataset_folder, get_filenames_in_folder

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_ROOT = '/datadrive'
SIMPSONS_FOLDER = os.path.join(DATA_ROOT, 'simpsons')
SIMPSONS_ORIGINAL = os.path.join(SIMPSONS_FOLDER, 'simpsons_selected')
SIMPSONS_ROOT = os.path.join(SIMPSONS_FOLDER, 'simpsons')

# %%
print(get_filenames_in_folder(SIMPSONS_ORIGINAL))
# Out:
# ['abraham_grampa_simpson', 'apu_nahasapeemapetilon', 'bart_simpson', 'charles_montgomery_burns', 'chief_wiggum', 'comic_book_guy', 'edna_krabappel', 'homer_simpson', 'kent_brockman', 'krusty_the_clown', 'lenny_leonard', 'lisa_simpson', 'marge_simpson', 'mayor_quimby', 'milhouse_van_houten', 'moe_szyslak', 'ned_flanders', 'nelson_muntz', 'principal_skinner', 'sideshow_bob']

# %%
split_dataset_folder(SIMPSONS_ORIGINAL, SIMPSONS_ROOT)
# Out:
# Folder:  abraham_grampa_simpson
# Copying /datadrive/simpsons/simpsons_selected/abraham_grampa_simpson/pic_0000.jpg into /datadrive/simpsons/simpsons/train/abraham_grampa_simpson
# Copying /datadrive/simpsons/simpsons_selected/abraham_grampa_simpson/pic_0001.jpg into /datadrive/simpsons/simpsons/train/abraham_grampa_simpson
# Copying /datadrive/simpsons/simpsons_selected/abraham_grampa_simpson/pic_0002.jpg into /datadrive/simpsons/simpsons/train/abraham_grampa_simpson
# Copying /datadrive/simpsons/simpsons_selected/abraham_grampa_simpson/pic_0003.jpg into /datadrive/simpsons/simpsons/train/abraham_grampa_simpson
# Copying /datadrive/simpsons/simpsons_selected/abraham_grampa_simpson/pic_0004.jpg into /datadrive/simpsons/simpsons/train/abraham_grampa_simpson
# Copying /datadrive/simpsons/simpsons_selected/abraham_grampa_simpson/pic_0005.jpg into /datadrive/simpsons/simpsons/train/abraham_grampa_simpson
# ...
