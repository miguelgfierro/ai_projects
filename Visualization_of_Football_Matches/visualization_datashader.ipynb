# %% [markdown]
# ## Visualization of Football Matches using the Lean Startup Method
#
# Visualization is one of the key parts in a Data Science project. It allows us to get a global sense of our data and to understand better our results.
# There are many free and non-free tools in the market to make data visualization. One of my favourites is [datashader](https://github.com/bokeh/datashader), an open source python library that allows to visualize big amounts of data with a clean and nice API.

# %%
#Load all libraries
import os,sys  
import pandas as pd
import numpy as np
import xarray as xr
import datashader as ds
import datashader.transfer_functions as tf
from datashader import reductions
from datashader.colors import colormap_select, Hot, inferno
from datashader.bokeh_ext import InteractiveImage
from bokeh.palettes import Greens3, Blues3, Blues9
from bokeh.plotting import figure, output_notebook
from bokeh.tile_providers import WMTSTileSource, STAMEN_TONER, STAMEN_TERRAIN
from functools import partial
import wget
import zipfile
import math
from difflib import SequenceMatcher

output_notebook()
#print(sys.path)
print(sys.version)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5eb428ab-d682-4762-b650-465b107aedb1">Loading BokehJS ...</span>
#     </div>
# 3.5.2 |Anaconda custom (64-bit)| (default, Jul  2 2016, 17:53:06)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]

# %% [markdown]
# ### Visualization of Champions League matches
# We can easily create a visualization of the Champion League matches from 1955 to 2016 using datashader. For that we need a dataset of the matches, such as [this one](https://github.com/jalapic/engsoccerdata/blob/master/data-raw/champs.csv) and the coordinates of the Stadiums of the teams, that you can find [here](http://opisthokonta.net/?cat=34).
#
# The first step is to treat the data.

# %%
df_stadium = pd.read_csv("stadiums.csv", usecols=['Team','Stadium','Latitude','Longitude','Country'])
print("Number of rows: %d" % df_stadium.shape[0])
dd1 = df_stadium.take([0,99, 64, 121])
dd1
# Out:
# Number of rows: 164
#                      Team             Stadium   Latitude  Longitude  Country
# 0                Arsenal    Emirates Stadium   51.555000  -0.108611  England
# 99           Real Madrid   Santiago Bernabéu   40.453060  -3.688350    Spain
# 64         Bayern Munich       Allianz Arena   48.218775  11.624753  Germany
# 121  Paris Saint-Germain    Parc des Princes   48.841389   2.253056   France

# %% [markdown]
# The next step is to match the club names in the dataset of coordinates with the those in the dataset of matches. They are similar but not always exactly the same, for example, in the dataset of coordinates we have `Real Madrid FC` and in the dataset of matches we have `Real Madrid`. Furthermore, in the first one there are several entries for some teams, like `Atletico Madrid`, `Atletico Madrid B` or `Atletico Madrid C` meaning they are the teams from the first division and from other divisions.

# %%
df_match = pd.read_csv('champions.csv', usecols=['Date','home','visitor','hcountry','vcountry'])
df_match = df_match.rename(columns = {'hcountry':'home_country', 'vcountry':'visitor_country'})
df_teams_champions = pd.concat([df_match['home'], df_match['visitor']])
teams_champions = set(df_teams_champions)
print("Number of teams that have participated in the Champions League: %d" % len(teams_champions))
print("Number of matches in the dataset: %d" % df_match.shape[0])
df_match.head()
# Out:
# Number of teams that have participated in the Champions League: 502
# Number of matches in the dataset: 6554
#          Date                    home            visitor home_country  \
# 0  1955-09-04             Sporting CP  Partizan Belgrade          POR
# 1  1955-09-07  Budapesti Voros Lobogo     RSC Anderlecht          HUN
# 2  1955-09-08         Servette Geneve        Real Madrid          SUI
# 3  1955-09-14         Rot-Weiss Essen       Hibernian FC          GER
# 4  1955-09-20          Djurgardens IF   Gwardia Warszawa          SWE
#
#   visitor_country
# 0             SRB
# 1             BEL
# 2             ESP
# 3             SCO
# 4             POL

# %% [markdown]
# To find the string similarity you can use different methods. Here we will use a simple method to calculate it with `difflib`.

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

def get_info_similar_team(team, df_stadium, threshold=0.6, verbose=False):
    max_rank = 0
    max_idx = -1
    stadium = "Unknown"
    latitude = np.NaN
    longitude = np.NaN
    for idx, val in enumerate(df_stadium['Team']):
        rank = similar(team, val)
        if rank > threshold:
            if(verbose): print("%s and %s(Idx=%d) are %f similar." % (team, val, idx, rank))
            if rank > max_rank:
                if(verbose): print("New maximum rank: %f" %rank)
                max_rank = rank
                max_idx = idx
                stadium = df_stadium['Stadium'].iloc[max_idx]
                latitude = df_stadium['Latitude'].iloc[max_idx]
                longitude = df_stadium['Longitude'].iloc[max_idx]
    return stadium, latitude, longitude
print(get_info_similar_team("Real Madrid FC", df_stadium, verbose=True))
print(get_info_similar_team("Atletico de Madrid FC", df_stadium, verbose=True))
print(get_info_similar_team("Inter Milan", df_stadium, verbose=True))
# Out:
# Real Madrid FC and Real Madrid (Idx=99) are 0.923077 similar.
# New maximum rank: 0.923077
# ('Santiago Bernabéu ', 40.453060000000001, -3.6883499999999998)
# Atletico de Madrid FC and Atlético Madrid (Idx=87) are 0.810811 similar.
# New maximum rank: 0.810811
# ('Vicente Calderón ', 40.401719, -3.7206059999999996)
# ('Unknown', nan, nan)

# %% [markdown]
# The next step is to create a dataframe relating each match with the stadium coordinates of each team

# %%
# %%time
df_match_stadium = df_match
home_stadium_index = df_match_stadium['home'].map(lambda x: get_info_similar_team(x, df_stadium))
visitor_stadium_index = df_match_stadium['visitor'].map(lambda x: get_info_similar_team(x, df_stadium))
df_home = pd.DataFrame(home_stadium_index.tolist(), columns=['home_stadium', 'home_latitude', 'home_longitude'])
df_visitor = pd.DataFrame(visitor_stadium_index.tolist(), columns=['visitor_stadium', 'visitor_latitude', 'visitor_longitude'])
df_match_stadium = pd.concat([df_match_stadium, df_home, df_visitor], axis=1, ignore_index=False)
# Out:
# CPU times: user 1min 52s, sys: 416 ms, total: 1min 53s
# Wall time: 1min 53s

# %%
print("Number of missing values: %d out of %d" % (df_match_stadium['home_stadium'].value_counts()['Unknown'], df_match_stadium.shape[0]))
df1 = df_match_stadium['home_stadium'] == 'Unknown'
df2 = df_match_stadium['visitor_stadium'] == 'Unknown'
n_complete_matches = df_match_stadium.shape[0] - df_match_stadium[df1 | df2].shape[0]
print("Number of matches with complete data: %d" % n_complete_matches)
df_match_stadium.head()
# Out:
# Number of missing values: 4499 out of 6554
# Number of matches with complete data: 728
#          Date                    home            visitor home_country  \
# 0  1955-09-04             Sporting CP  Partizan Belgrade          POR
# 1  1955-09-07  Budapesti Voros Lobogo     RSC Anderlecht          HUN
# 2  1955-09-08         Servette Geneve        Real Madrid          SUI
# 3  1955-09-14         Rot-Weiss Essen       Hibernian FC          GER
# 4  1955-09-20          Djurgardens IF   Gwardia Warszawa          SWE
#
#   visitor_country home_stadium  home_latitude  home_longitude  \
# 0             SRB   El Molinón      43.536111       -5.637222
# 1             BEL      Unknown            NaN             NaN
# 2             ESP      Unknown            NaN             NaN
# 3             SCO      Unknown            NaN             NaN
# 4             POL      Unknown            NaN             NaN
#
#       visitor_stadium  visitor_latitude  visitor_longitude
# 0             Unknown               NaN                NaN
# 1             Unknown               NaN                NaN
# 2  Santiago Bernabéu          40.453060          -3.688350
# 3        Easter Road          55.961667          -3.165556
# 4             Unknown               NaN                NaN

# %% [markdown]
# Now, even though there are many entries in the dataset that don't have any value, we are going to create a dataframe with the teams that do have values and advance in the project. This dataframe finds the combination of teams (home and visitor) that have values and concatenate each other to create the map.

# %%
def aggregate_dataframe_coordinates(dataframe):
    df = pd.DataFrame(index=np.arange(0, n_complete_matches*3), columns=['Latitude','Longitude'])
    count = 0
    for ii in range(dataframe.shape[0]):
        if dataframe['home_stadium'].loc[ii]!= 'Unknown' and dataframe['visitor_stadium'].loc[ii]!= 'Unknown':
            df.loc[count] = [dataframe['home_latitude'].loc[ii], dataframe['home_longitude'].loc[ii]]
            df.loc[count+1] = [dataframe['visitor_latitude'].loc[ii], dataframe['visitor_longitude'].loc[ii]]
            df.loc[count+2] = [np.NaN, np.NaN]
            count += 3
    return df
df_agg = aggregate_dataframe_coordinates(df_match_stadium)
df_agg.head()
# Out:
#   Latitude Longitude
# 0  53.4631  -2.29139
# 1  51.4926   7.45184
# 2      NaN       NaN
# 3  55.8532  -4.30926
# 4  43.7233   7.25876

# %% [markdown]
# We have to transform the latitude and longitude coordinates to [web mercator](https://en.wikipedia.org/wiki/Web_Mercator) format in order to be able to represent it in a map using bokeh. Mercator coordinates are a cilindrical projection of the World coordinates. It was invented in 1569 by [Gerardus Mercator](https://en.wikipedia.org/wiki/Mercator_projection) and became the standard format for nautical purposes. The web mercator format is an adaptation of the original mercator format and it is currently used by most modern map systems such as Google Maps, Bing Maps or OpenStreetMaps.

# %%
def to_web_mercator(yLat, xLon):
    # Check if coordinate out of range for Latitude/Longitude
    if (abs(xLon) > 180) and (abs(yLat) > 90):  
        return
 
    semimajorAxis = 6378137.0  # WGS84 spheriod semimajor axis
    east = xLon * 0.017453292519943295
    north = yLat * 0.017453292519943295
 
    northing = 3189068.5 * math.log((1.0 + math.sin(north)) / (1.0 - math.sin(north)))
    easting = semimajorAxis * east
 
    return [easting, northing]
df_agg_mercator = df_agg.apply(lambda row: to_web_mercator(row['Latitude'], row['Longitude']), axis=1)
df_agg_mercator.head()
# Out:
#         Latitude     Longitude
# 0 -255076.256689  7.069114e+06
# 1  829535.256912  6.708890e+06
# 2            NaN           NaN
# 3 -479704.406257  7.529248e+06
# 4  808041.021713  5.422726e+06

# %% [markdown]
# The next step is to plot the trayectories in the map using datashader

# %%
plot_width  = 850
plot_height = 600
x_range = (-2.0e6, 2.5e6)
y_range = (4.1e6, 7.8e6)
def create_image(x_range=x_range, y_range=y_range, w=plot_width, h=plot_height):
    cvs = ds.Canvas(plot_width=w, plot_height=h, x_range=x_range, y_range=y_range)
    agg = cvs.line(df_agg_mercator, 'Latitude', 'Longitude',  ds.count())
    img = tf.shade(agg, cmap=Blues9, how='eq_hist')
        
    return img

def base_plot(tools='pan,wheel_zoom,reset',plot_width=plot_width, plot_height=plot_height,**plot_args):
    p = figure(tools=tools, plot_width=plot_width, plot_height=plot_height,
        x_range=x_range, y_range=y_range, outline_line_color=None,
        min_border=0, min_border_left=0, min_border_right=0,
        min_border_top=0, min_border_bottom=0, **plot_args)
    
    p.axis.visible = False
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    
    return p

ArcGIS=WMTSTileSource(url='http://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{Z}/{Y}/{X}.png')
p = base_plot()
p.add_tile(ArcGIS)
InteractiveImage(p, create_image)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9caffd54-9bcc-4df9-94a6-ea848473450a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9caffd54-9bcc-4df9-94a6-ea848473450a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("341c955b-9450-44af-9460-b063a9f6fdee", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9caffd54-9bcc-4df9-94a6-ea848473450a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9caffd54-9bcc-4df9-94a6-ea848473450a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"83add15f-426b-4a23-981d-daa5268dcf46":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"1f262902-b023-4159-9925-f01909c6e79b","type":"Title"},{"attributes":{"args":{"x_range":{"id":"730e016f-89f1-43cd-a648-1feb2e1d4ffb","type":"Range1d"},"y_range":{"id":"0822ecbd-e860-469e-8b27-913f18426dda","type":"Range1d"}},"code":"\n        // Define a callback to capture errors on the Python side\n        function callback(msg){\n          if (msg.msg_type == \"execute_result\") {\n            if (msg.content.data['text/plain'] === \"'Complete'\") {\n               if (Bokeh._queued.length) {\n                   update_plot();\n               } else {\n                   Bokeh._blocked = false;\n               }\n               Bokeh._timeout = Date.now();\n            }\n          } else {\n            console.log(\"Python callback returned unexpected message:\", msg)\n          }\n        }\n        callbacks = {iopub: {output: callback}};\n\n        function update_plot() {\n            range = Bokeh._queued;\n            var cmd = \"from datashader.bokeh_ext import InteractiveImage; InteractiveImage._callbacks['341c955b-9450-44af-9460-b063a9f6fdee'].update(\" + range + \")\"\n            // Execute the command on the Python kernel\n            if (IPython.notebook.kernel !== undefined) {\n                var kernel = IPython.notebook.kernel;\n                kernel.execute(cmd, callbacks, {silent : false});\n            }\n            Bokeh._queued = [];\n        }\n\n        var plot = x_range.plots[0];\n        // Generate a command to execute in Python\n        var ranges = {xmin: x_range.start,\n                       ymin: y_range.start,\n                       xmax: x_range.end,\n                       ymax: y_range.end,\n                       w: Math.floor(plot.width),\n                       h: Math.floor(plot.height)}\n        var range_str = JSON.stringify(ranges)\n\n        if (!Bokeh._queued) {\n            Bokeh._queued = [];\n            Bokeh._blocked = false;\n            Bokeh._timeout = Date.now();\n        }\n\n        timeout = Bokeh._timeout + 2000;\n        if (typeof _ === \"undefined\") {\n        } else if ((Bokeh._blocked && (Date.now() < timeout))) {\n            Bokeh._queued = [range_str];\n        } else {\n            Bokeh._queued = [range_str];\n            setTimeout(update_plot(), 200);\n            Bokeh._blocked = true;\n            Bokeh._timeout = Date.now();\n        }\n    "},"id":"61e0fa17-d386-4905-8c33-5f614a29bc66","type":"CustomJS"},{"attributes":{"plot":{"id":"85e69355-a87f-4f42-b89e-cd40c081073b","subtype":"Figure","type":"Plot"}},"id":"b1789cd5-bf9c-4a16-8c50-0c1d4b9e77a1","type":"PanTool"},{"attributes":{},"id":"f1e9ad41-8319-4efc-9faf-c5b728066293","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"39e2ae0d-aa81-48a8-8531-cd1cf750d801","type":"LinearAxis"}],"left":[{"id":"0a378f5f-e943-40ea-be9b-942ddf0f069c","type":"LinearAxis"}],"min_border":0,"min_border_bottom":0,"min_border_left":0,"min_border_right":0,"min_border_top":0,"outline_line_color":{"value":null},"plot_width":850,"renderers":[{"id":"39e2ae0d-aa81-48a8-8531-cd1cf750d801","type":"LinearAxis"},{"id":"a0f344cb-1412-43ea-93aa-6527df9d92fb","type":"Grid"},{"id":"0a378f5f-e943-40ea-be9b-942ddf0f069c","type":"LinearAxis"},{"id":"3de0e2e4-2912-478a-a24d-1c8625b5f7a5","type":"Grid"},{"id":"7d2546d8-a64c-478b-b3a7-116a9e62b540","type":"TileRenderer"},{"id":"9f42c51f-c42f-4b98-bb6a-95ea9d5773a0","type":"GlyphRenderer"}],"title":{"id":"1f262902-b023-4159-9925-f01909c6e79b","type":"Title"},"tool_events":{"id":"68e70f74-5e08-451e-8b60-6a735bba4b08","type":"ToolEvents"},"toolbar":{"id":"bda7ba9b-5e00-4953-a8a0-309fc7e26e76","type":"Toolbar"},"x_range":{"id":"730e016f-89f1-43cd-a648-1feb2e1d4ffb","type":"Range1d"},"y_range":{"id":"0822ecbd-e860-469e-8b27-913f18426dda","type":"Range1d"}},"id":"85e69355-a87f-4f42-b89e-cd40c081073b","subtype":"Figure","type":"Plot"},{"attributes": ...

# %% [markdown]
# Now that we have the map we can start to improve it. If you are into football, you will notice that there are several points in the north of Spain, that corresponds to Sporting de Gijon. Sadly for Sporting supporters, they have never reached to the Champions. Instead, Sporting Clube de Portugal has participated several times in the championship, but since the current dataset doesn't have teams from Portugal, the system mistakenly thinks that `Sporting CP` from `champions.csv` is the Sporting de Gijon from `stadiums.csv`. So lets fix this issue by getting the stadiums coordinates from the rest of the countries in Europe.
# We can get that info from [wikidata](https://query.wikidata.org/). Using `SPARQL` language we can get the information we need:
# ```SQL
# SELECT ?clubLabel ?venueLabel ?coordinates ?countryLabel  WHERE {
#   ?club wdt:P31 wd:Q476028.
#   ?club wdt:P115 ?venue.
#   ?venue wdt:P625 ?coordinates.
#   ?club wdt:P17 ?country.
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
# }
# ORDER BY ?clubLabel
# ```
# This generates 4435 Results in 10111 ms that can be saved to a csv file.

# %%
df_stadium_read = pd.read_csv('stadiums_wikidata.csv', usecols=['clubLabel','venueLabel','coordinates','countryLabel'])
df_stadium_read.tail()
# Out:
#                  clubLabel                 venueLabel  \
# 4430          ŠK SFM Senec                  NTC Senec
# 4431  ŠK Slovan Bratislava           Štadión Pasienky
# 4432          Żurrieq F.C.  Ta' Qali National Stadium
# 4433     ŽFK Crvena zvezda           Red Star Stadium
# 4434   ŽP Šport Podbrezová           Stadium Kolkáreň
#
#                            coordinates countryLabel
# 4430        Point(17.410412 48.217703)     Slovakia
# 4431        Point(17.141111 48.166111)     Slovakia
# 4432  Point(14.415372222 35.894863888)        Malta
# 4433          Point(20.464914 44.7832)       Serbia
# 4434             Point(19.535 48.8167)     Slovakia

# %% [markdown]
# The first step is to clean the column coordinates. For that we will use a regex pattern. The pattern `[-+]?[0-9]*\.?[0-9]+` finds any signed float in a string. Then we create two patterns separated by a space and name the columns using this format: `(?P<Longitude>)`. Finally we have to concatente the club information with the coordinates.

# %%
df_temp = df_stadium_read['coordinates'].str.extract('(?P<Longitude>[-+]?[0-9]*\.?[0-9]+) (?P<Latitude>[-+]?[0-9]*\.?[0-9]+)', expand=True)
df_stadium_new = pd.concat([df_stadium_read['clubLabel'],df_stadium_read['venueLabel'], df_temp, df_stadium_read['countryLabel']], axis=1) 
df_stadium_new = df_stadium_new.rename(columns = {'clubLabel':'Team', 'venueLabel':'Stadium','countryLabel':'Country'})
print("Number of rows: %d" % df_stadium_new.shape[0])
unique_teams_stadium = list(set(df_stadium_new['Team']))
print("Unique team's name number: %d" % len(unique_teams_stadium))
df_stadium_new.take(list(range(3388,3393)))
# Out:
# Number of rows: 4435
# Unique team's name number: 4314
#                   Team                      Stadium    Longitude     Latitude  \
# 3388       Real Madrid  Juan Ramón Loubriel Stadium   -66.150833    18.393333
# 3389       Real Madrid            Galeshewe Stadium    24.740857   -28.716786
# 3390     Real Madrid C           Ciudad Real Madrid  -3.61166667  40.47916667
# 3391  Real Madrid C.F.           Ciudad Real Madrid  -3.61166667  40.47916667
# 3392    Real Madrid FC    Estadio Santiago Bernabéu     -3.68835     40.45306
#
#                        Country
# 3388  United States of America
# 3389              South Africa
# 3390                     Spain
# 3391                     Spain
# 3392                     Spain

# %% [markdown]
# As it can be seen in the previous dataframe, we came into another problem. The new dataset contains all team instances, all over the world. There are some teams that have the same name in different countries, there is a Real Madrid team from USA and South Africa, and a similar name within a country. In our case, we are only interested in the instance `Real Madrid, Estadio Santiago Bernabeu, -3.68835, 40.45306, Spain`. So how can we find an automated way to filter the correct teams that have participated in the Champions League?
#
# A practical approach is to combine an automated and manual way. With the data we have so far we can automatically filter the two first entries using the country. We can get the country info from `champions.csv` dataset. To distinguish teams from the same country we will filter them manually.
#
# The first step then is to get a dataframe with all the teams that have participated in Champions and their country of origin. Then we have to remove the repeated entries and rename the country code to the country name that can be found in wikidata.

# %%
df_match_home = df_match[['home','home_country']]
df_match_home = df_match_home.rename(columns={'home':'Team','home_country':'Country'})
df_match_visitor = df_match[['visitor','visitor_country']]
df_match_visitor = df_match_visitor.rename(columns={'visitor':'Team','visitor_country':'Country'})
df_champions_teams = pd.concat([df_match_home,df_match_visitor], axis=0, ignore_index=True)
df_champions_teams = df_champions_teams.drop_duplicates()
print("Number of unique teams: %d" % df_champions_teams.shape[0])
country_dict = {'ALB':'Albania',
                'AND':'Andorra',
                'ARM':'Armenia',
                'AUT':'Austria',
                'AZE':'Azerbaijan',
                'BEL':'Belgium',
                'BIH':'Bosnia and Herzegovina',
                'BLR':'Belarus',
                'BUL':'Bulgaria',
                'CRO':'Croatia',
                'CYP':'Cyprus',
                'CZE':'Czech Republic',
                'DEN':'Denmark',
                'ENG':'England',
                'ESP':'Spain',
                'EST':'Estonia',
                'FIN':'Finland',
                'FRA':'France',
                'FRO':'Feroe Islands',
                'GEO':'Georgia',
                'GER':'Germany',
                'GIB':'Gibraltar',
                'GRE':'Greece',
                'HUN':'Hungary',
                'ITA':'Italy',
                'IRL':'Ireland',
                'ISL':'Iceland',
                'ISR':'Israel',
                'KAZ':'Kazakhstan',
                'LTU':'Lithuania',
                'LUX':'Luxembourg',
                'LVA':'Latvia',
                'MDA':'Moldova',
                'MKD':'Macedonia',
                'MLT':'Malta',
                'MNE':'Montenegro',
                'NED':'Netherlands',
                'NIR':'Northern Ireland',
                'NOR':'Norwey',
                'POL':'Poland',
                'POR':'Portugal',
                'ROU':'Romania',
                'RUS':'Russia',
                'SCO':'Scotland',
                'SMR':'San Marino',
                'SRB':'Serbia',
                'SUI':'Switzerland',
                'SVK':'Slovakia',
                'SVN':'Slovenia',
                'SWE':'Sweden',
                'TUR':'Turkey',
                'UKR':'Ukrania',
                'WAL':'Wales'}
df_champions_teams['Country'].replace(country_dict, inplace=True)
#df_champions_teams.to_csv('match_unique.csv')# To check that the mapping is correct
df_champions_teams.sort_values(by='Team',inplace=True)
df_champions_teams = df_champions_teams.reset_index(drop=True)
df_champions_teams.head()
# Out:
# Number of unique teams: 502
#                Team         Country
# 0  AC Chievo Verona           Italy
# 1          AC Milan           Italy
# 2   AC Sparta Praha  Czech Republic
# 3    ACF Fiorentina           Italy
# 4         AE Larisa          Greece

# %% [markdown]
# Once we have the list of all teams that have participated in the Champions League, we have to generate a new dataset relating each Champions League matches with the coordinates of the team stadiums. For that we will use the function `similar` to match a the name of the team in the different datasets similarly as we did before.
# Once the

# %%
# %%time
def get_info_similar_team_country(team, country, df_stadium, df, threshold=0.6, verbose=False):
    team2 = "Unknown"
    stadium = "Unknown"
    latitude = np.NaN
    longitude = np.NaN
    cols = list(df)
    for idx, val in enumerate(df_stadium['Team']):
        rank = similar(team, val)
        if rank > threshold and country == df_stadium['Country'].iloc[idx]:
            if(verbose): print("%s and %s(Idx=%d) are %f similar and from the same country %s." 
                               % (team, val, idx, rank, country))
            team2 = df_stadium['Team'].iloc[idx]
            stadium = df_stadium['Stadium'].iloc[idx]
            latitude = df_stadium['Latitude'].iloc[idx]
            longitude = df_stadium['Longitude'].iloc[idx]
            dtemp = pd.DataFrame([[team, team2, stadium, latitude, longitude, country]], columns=cols)
            df = df.append(dtemp, ignore_index=True)
    #if there is no match, register it
    if(team2 == "Unknown"):
        df_nomatch = pd.DataFrame([[team, team2, stadium, latitude, longitude, country]], columns=cols)
        df = df.append(df_nomatch, ignore_index=True)
    return df

def generate_new_stadium_dataset(df_champions_teams, df_stadium_new):
    df = pd.DataFrame(columns=['Team', 'Team2', 'Stadium', 'Latitude','Longitude','Country'])
    for idx, row in df_champions_teams.iterrows():
        df = get_info_similar_team_country(row['Team'],row['Country'], df_stadium_new, df, verbose=True)
    return df

df_stadiums_champions = generate_new_stadium_dataset(df_champions_teams, df_stadium_new)
df_stadiums_champions.to_csv('stadiums_champions.csv', index=False)
df_stadiums_champions.head()
# Out:
# AC Chievo Verona and A.C. ChievoVerona(Idx=63) are 0.909091 similar and from the same country Italy.
# AC Milan and A.C. Milan(Idx=66) are 0.888889 similar and from the same country Italy.
# AC Sparta Praha and AC Sparta Prague(Idx=123) are 0.838710 similar and from the same country Czech Republic.
# ACF Fiorentina and ACF Fiorentina(Idx=125) are 1.000000 similar and from the same country Italy.
# AEK Athens and A.E.K. Athens F.C.(Idx=81) are 0.714286 similar and from the same country Greece.
# AEL Limassol and AEL Limassol FC(Idx=150) are 0.888889 similar and from the same country Cyprus.
# AEL Limassol and Amathus Limassol(Idx=375) are 0.714286 similar and from the same country Cyprus.
# AEL Limassol and Antaeus Limassol(Idx=403) are 0.714286 similar and from the same country Cyprus.
# AEL Limassol and Apollon Limassol(Idx=407) are 0.714286 similar and from the same country Cyprus.
# AEL Limassol and Apollon Limassol(Idx=408) are 0.714286 similar and from the same country Cyprus.
# AEL Limassol and Aris Limassol F.C.(Idx=422) are 0.666667 similar and from the same country Cyprus.
# AEL Limassol and Lenas Limassol(Idx=2640) are 0.769231 similar and from the same country Cyprus.
# AFC Ajax and A.F.C. Ajax(Idx=82) are 0.842105 similar and from the same country Netherlands.
# AFC Ajax and AFC Ajax (women)(Idx=156) are 0.666667 similar and from the same country Netherlands.
# AJ Auxerre and A.J. Auxerre(Idx=87) are 0.909091 similar and from the same country France.
# AS Monaco and A.S. Monaco F.C.(Idx=93) are 0.720000 similar and from the same country France.
# AS Monaco and A.S. Mont-Dore(Idx=94) are 0.608696 similar and from the same country France.
# AS Monaco and AS Magenta(Idx=185) are 0.631579 similar and from the same country France.
# AS Roma and A.S. Roma(Idx=97) are 0.875000 similar and from the same country Italy.
# AS Saint-Etienne and A.S. Saint-Étienne(Idx=98) are 0.882353 similar and from the same country France.
# AS Trencin and FK AS Trenčín(Idx=1949) are 0.695652 similar and from the same country Slovakia.
# AZ Alkmaar and AZ Alkmaar(Idx=205) are 1.000000 similar and from the same country Netherlands.
# Aarhus GF and VSK Aarhus(Idx=4197) are 0.631579 similar and from the same country Denmark.
# Admira Wien and FK Austria Wien(Idx=1951) are 0.615385 similar and from the same country Austria.
# Aktobe and FC Aktobe(Idx=1569) are 0.800000 similar and from the same country Kazakhstan.
# Alania Vladikavkaz and FC Alania Vladikavkaz(Idx=1571) are 0.923077 similar and from the same country Russia.
# Alania Vladikavkaz and FC Alania-d Vladikavkaz(Idx=1572) are 0.878049 similar and from the same country Russia.
# Anorthosis Famagusta and Anorthosis Famagusta FC(Idx=401) are 0.930233 similar and from the same country Cyprus.
# Anorthosis Famagusta and Anorthosis Kato Polemidia(Idx=402) are 0.622222 similar and from the same country Cyprus.
# Anorthosis Famagusta and Othellos Famagusta(Idx=3094) are 0.736842 similar and from the same country Cyprus.
# Apollon Limassol and AEL Limassol FC(Idx=150) are 0.645161 similar and from the same country Cyprus.
# Apollon Limassol and Amathus Limassol(Idx=375) are 0.625000 similar and from the same country Cyprus.
# Apollon Limassol and Antaeus Limassol(Idx=403) are 0.687500 similar and from the same country Cyprus.
# Apollon Limassol and Apollon Limassol(Idx=407) are 1.000000 similar and from the same country Cyprus.
# Apollon Limassol and Apollon Limassol(Idx=408) are 1.000000 similar and from the same country Cyprus.
# Apollon Limassol and Apollon Lympion(Idx=409) are 0.709677 similar and from the same country Cyprus.
# Apollon Limassol and ENAZ Agia Zoni Limassol(Idx=1391) are 0.615385 similar and from the same country Cyprus.
# Apollon Limassol and Lenas Limassol(Idx=2640) are 0.666667 similar and from the same country Cyprus.
# Apollon Limassol and Panellinios Limassol(Idx=3164) are 0.666667 similar and from the same country Cyprus.
# Arges Pitesti and FC Argeș Pitești(Idx=1581) are 0.758621 similar and from the same country Romania.
# Astana and FC Astana(Idx=1586) are 0.800000 similar and from the same country Kazakhstan.
# Astana-64 and FC Astana(Idx=1586) are 0.666667 similar and from the same country Kazakhstan.
# Astana-64 and FC Astana-1964(Idx=1587) are 0.782609 similar and from the same country Kazakhstan.
# Athletic Bilbao and Athletic Bilbao B(Idx=483) are 0.937500 similar and from the same country Spain.
# Athletic Bilbao and Athletic Club(Idx=484) are 0.785714 similar and from the same country Spain.
# Athletic Bilbao and Athletic Club(Idx=485) are 0.785714 similar and from the same country Spain.
# Athlone Town and Athlone Town F.C.(Idx=486) are 0.827586 similar and from the same country Ireland.
# Atletico Madrid and Atlético Madrid(Idx=514) are 0.933333 similar and from the same country Spain.
# Atletico Madrid and Atlético Madrid B(Idx=515) are 0.875000 similar and from the same country Spain.
# Atletico Madrid and Atlético Madrid C(Idx=516) are 0.875000 similar and from the same country Spain.
# Atletico Madrid and Atlético Madrid Femenino(Idx=517) are 0.717949 similar and from the same country Spain.
# Atvidabergs FF and Åtvidabergs FF(Idx=4404) are 0.928571 similar and from the same country Sweden.
# Austria Wien and FK Austria Wien(Idx=1951) are 0.888889 similar and from the same country Austria.
# Austria Wien and SC Austria Lustenau(Idx=3514) are 0.645161 similar and from the same country Austria.
# Austria Wien and SK Austria Klagenfurt(Idx=3560) are 0.606061 similar and from the same country Austria.
# Austria Wien and SK Austria Kärnten(Idx=3561) are 0.666667 similar and from the same country Austria.
# BATE Borisov and FC BATE Borisov(Idx=1592) are 0.888889 similar and from the same country Belarus.
# BFC Dynamo and Berliner FC Dynamo(Idx=634) are 0.714286 similar and from the same country Germany.
# BSC Young Boys and BSC Old Boys(Idx=563) are 0.692308 similar and from the same country Switzerland.
# BSC Young Boys and BSC Young Boys(Idx=565) are 1.000000 similar and from the same country Switzerland.
# BSG Chemie Leipzig and 1. FC Lokomotive Leipzig(Idx=37) are 0.619048 similar and from the same country Germany.
# BSG Chemie Leipzig and BSG Chemie Leipzig(Idx=566) are 1.000000 similar and from the same country Germany.
# BSG Chemie Leipzig and RB Leipzig(Idx=3337) are 0.642857 similar and from the same country Germany.
# Baku and FC Baku(Idx=1594) are 0.727273 similar and from the same country Azerbaijan.
# Baku and MOIK Baku(Idx=2731) are 0.615385 similar and from the same country Azerbaijan.
# Banants and FC Banants(Idx=1596) are 0.823529 similar and from the same country Armenia.
# Banik Ostrava and FC Baník Ostrava(Idx=1597) are 0.827586 similar and from the same country Czech Republic.
# Barcelona and FC Barcelona(Idx=1598) are 0.857143 similar and from the same country Spain.
# Barcelona and FC Barcelona(Idx=1599) are 0.857143 similar and from the same country Spain.
# Barcelona and FC Barcelona B(Idx=1600) are 0.782609 similar and from the same country Spain.
# Barcelona and FC Barcelona C(Idx=1601) are 0.782609 similar and from the same country Spain.
# Barcelona and FC Barcelona Hoquei(Idx=1602) are 0.642857 similar and from the same country Spain.
# Basel and FC Basel(Idx=1603) are 0.769231 similar and from the same country Switzerland.
# Bayer Leverkusen and Bayer 04 Leverkusen(Idx=612) are 0.914286 similar and from the same country Germany.
# Bayer Leverkusen and Bayer 04 Leverkusen(Idx=613) are 0.914286 similar and from the same country Germany.
# Bayern Munich and FC Bayern Munich(Idx=1606) are 0.896552 similar and from the same country Germany.
# Bayern Munich and FC Bayern Munich(Idx=1607) are 0.896552 similar and from the same country Germany.
# Beitar Jerusalem and Beitar Jerusalem F.C.(Idx=621) are 0.864865 similar and from the same country Israel.
# Boavista and Boavista F.C.(Idx=658) are 0.761905 similar and from the same country Portugal.
# Bohemians and Bohemian F.C.(Idx=665) are 0.727273 similar and from the same country Ireland.
# Bohemians and Bohemian F.C.(Idx=666) are 0.727273 similar and from the same country Ireland.
# Bohemians and Cork Bohemians F.C.(Idx=1200) are 0.642857 similar and from the same country Ireland.
# Bohemians EKD Praha and Bohemians 1905(Idx=667) are 0.606061 similar and from the same country Czech Republic.
# Bohemians EKD Praha and FK Bohemians Prague(Idx=1964) are 0.684211 similar and from the same country Czech Republic.
# Borac Banja Luka and FK Borac Banja Luka(Idx=1965) are 0.914286 similar and from the same country Bosnia and Herzegovina.
# Borussia Dortmund and Borussia Fulda(Idx=676) are 0.709677 similar and from the same country Germany.
# Borussia Monchengladbach and Borussia Mönchengladbach(Idx=677) are 0.958333 similar and from the same country Germany.
# Borussia Monchengladbach and Borussia Neunkirchen(Idx=678) are 0.636364 similar and from the same country Germany.
# Breidablik and Breiðablik UBK(Idx=700) are 0.750000 similar and from the same country Iceland.
# Brondby IF and Brøndby IF(Idx=713) are 0.900000 similar and from the same country Denmark.
# Budapest Honved SE and Budapest Honvéd FC(Idx=717) are 0.833333 similar and from the same country Hungary.
# Bursaspor and Bucaspor(Idx=714) are 0.823529 similar and from the same country Turkey.
# Bursaspor and Bursaspor(Idx=725) are 1.000000 similar and from the same country Turkey.
# Bursaspor and Manisaspor(Idx=2776) are 0.631579 similar and from the same country Turkey.
# Bursaspor and Şanlıurfaspor(Idx=4429) are 0.636364 similar and from the same country Turkey.
# CCA Bucuresti and FC Dinamo București(Idx=1642) are 0.625000 similar and from the same country Romania.
# CCA Bucuresti and FC Rapid București(Idx=1805) are 0.645161 similar and from the same country Romania.
# CCA Bucuresti and Venus București(Idx=4232) are 0.642857 similar and from the same country Romania.
# CDNA Sofia and AS 23 Sofia(Idx=172) are 0.666667 similar and from the same country Bulgaria.
# CDNA Sofia and PFC CSKA - Sofia(Idx=3112) are 0.615385 similar and from the same country Bulgaria.
# CFR Cluj and CFF Clujana(Idx=844) are 0.736842 similar and from the same country Romania.
# CFR Cluj and CFR Cluj(Idx=846) are 1.000000 similar and from the same country Romania.
# CSKA Moskva and PFC CSKA Moscow(Idx=3113) are 0.615385 similar and from the same country Russia.
# CSKA Moskva and PFC CSKA Moscow(Idx=3114) are 0.615385 similar and from the same country Russia.
# CSKA Sofia and AS 23 Sofia(Idx=172) are 0.666667 similar and from the same country Bulgaria.
# CSKA Sofia and PFC CSKA - Sofia(Idx=3112) are 0.769231 similar and from the same country Bulgaria.
# CSKA Sofia and PFC Slavia Sofia(Idx=3131) are 0.615385 similar and from the same country Bulgaria.
# Cagliari Calcio and A.C. Perugia Calcio(Idx=69) are 0.647059 similar and from the same country Italy.
# Cagliari Calcio and A.C.D. Foggia Calcio(Idx=74) are 0.628571 similar and from the same country Italy.
# Cagliari Calcio and A.S. Casale Calcio(Idx=88) are 0.606061 similar and from the same country Italy.
# Cagliari Calcio and Brescia Calcio(Idx=702) are 0.620690 similar and from the same country Italy.
# Cagliari Calcio and Cagliari Calcio(Idx=884) are 1.000000 similar and from the same country Italy.
# Cagliari Calcio and Foligno Calcio(Idx=2099) are 0.620690 similar and from the same country Italy.
# Cagliari Calcio and Novara Calcio(Idx=3009) are 0.642857 similar and from the same country Italy.
# Cagliari Calcio and S.S. Chieti Calcio(Idx=3494) are 0.606061 similar and from the same country Italy.
# Cagliari Calcio and San Marino Calcio(Idx=3658) are 0.687500 similar and from the same country Italy.
# Cagliari Calcio and Spezia Calcio(Idx=3819) are 0.642857 similar and from the same country Italy.
# Cagliari Calcio and Ternana Calcio(Idx=3994) are 0.620690 similar and from the same country Italy.
# Cagliari Calcio and Trapani Calcio(Idx=4043) are 0.689655 similar and from the same country Italy.
# Celta Vigo and Celta Vigo B(Idx=927) are 0.909091 similar and from the same country Spain.
# Club Brugge and Club Brugge K.V.(Idx=1049) are 0.814815 similar and from the same country Belgium.
# Club Brugge and Club Brugge KV(Idx=1050) are 0.880000 similar and from the same country Belgium.
# Cork Celtic and Cork Celtic F.C.(Idx=1201) are 0.814815 similar and from the same country Ireland.
# Cork City and Cork City F.C.(Idx=1202) are 0.782609 similar and from the same country Ireland.
# Cork Hibernians and Cork Hibernians F.C.(Idx=1203) are 0.857143 similar and from the same country Ireland.
# Crvena Zvezda and ŽFK Crvena zvezda(Idx=4433) are 0.800000 similar and from the same country Serbia.
# DOS Utrecht and FC Utrecht(Idx=1896) are 0.761905 similar and from the same country Netherlands.
# DSO Spartak Hradec Kralove and FC Hradec Králové(Idx=1701) are 0.604651 similar and from the same country Czech Republic.
# DWS Amsterdam and Blauw-Wit Amsterdam(Idx=651) are 0.687500 similar and from the same country Netherlands.
# Debreceni VSC and Debreceni VSC(Idx=1255) are 1.000000 similar and from the same country Hungary.
# Deportivo La Coruna and Club Deportivo Lugo(Idx=1073) are 0.631579 similar and from the same country Spain.
# Deportivo La Coruna and Club Deportivo Numancia(Idx=1076) are 0.619048 similar and from the same country Spain.
# Deportivo La Coruna and Club Deportivo Ribaforada(Idx=1080) are 0.636364 similar and from the same country Spain.
# Deportivo La Coruna and Deportivo Alavés(Idx=1291) are 0.628571 similar and from the same country Spain.
# Deportivo La Coruna and Deportivo Aragón(Idx=1293) are 0.685714 similar and from the same country Spain.
# Deportivo La Coruna and Deportivo de La Coruña(Idx=1326) are 0.878049 similar and from the same country Spain.
# Dila Gori and FC Dila Gori(Idx=1640) are 0.857143 similar and from the same country Georgia.
# Dinamo Bucuresti and FC Dinamo București(Idx=1642) are 0.857143 similar and from the same country Romania.
# Dinamo Bucuresti and FC Dinamo II București(Idx=1643) are 0.789474 similar and from the same country Romania.
# Dinamo Bucuresti and Venus București(Idx=4232) are 0.645161 similar and from the same country Romania.
# Dinamo Bucuresti and Victoria București(Idx=4255) are 0.647059 similar and from the same country Romania.
# Dinamo Minsk and FC Dinamo Minsk(Idx=1644) are 0.888889 similar and from the same country Belarus.
# Dinamo Moskva and FC Dynamo Moscow(Idx=1659) are 0.620690 similar and from the same country Russia.
# Dinamo Tbilisi and FC Dinamo Tbilisi(Idx=1645) are 0.903226 similar and from the same country Georgia.
# Dinamo Tbilisi and FC Norchi Dinamo Tbilisi(Idx=1773) are 0.736842 similar and from the same country Georgia.
# Dinamo Tirana and KF Tirana(Idx=2510) are 0.636364 similar and from the same country Albania.
# Dinamo Tirana and KS Dinamo Tirana(Idx=2516) are 0.896552 similar and from the same country Albania.
# Dinamo Tirana and Partizani Tirana(Idx=3181) are 0.620690 similar and from the same country Albania.
# Dinamo Zagreb and N.K. Dinamo Zagreb(Idx=2900) are 0.838710 similar and from the same country Croatia.
# Djurgardens IF and Djurgårdens I.F.(Idx=1348) are 0.866667 similar and from the same country Sweden.
# Djurgardens IF and Djurgårdens IF Dam(Idx=1349) are 0.812500 similar and from the same country Sweden.
# Dnepr Mogilev and FC Dnepr Mogilev(Idx=1646) are 0.896552 similar and from the same country Belarus.
# Drogheda United and Drogheda United F.C.(Idx=1363) are 0.857143 similar and from the same country Ireland.
# Drogheda United and Monaghan United F.C.(Idx=2855) are 0.628571 similar and from the same country Ireland.
# Dukla Praha and FK Dukla Prague(Idx=1976) are 0.692308 similar and from the same country Czech Republic.
# Dukla Praha and FK Dukla Prague(Idx=1977) are 0.692308 similar and from the same country Czech Republic.
# Dundalk and Dundalk F.C.(Idx=1372) are 0.736842 similar and from the same country Ireland.
# Dynamo Dresden and Dynamo Dresden(Idx=1381) are 1.000000 similar and from the same country Germany.
# EPA Larnaca and AEK Larnaca F.C.(Idx=148) are 0.666667 similar and from the same country Cyprus.
# EPA Larnaca and Alki Larnaca F.C.(Idx=355) are 0.642857 similar and from the same country Cyprus.
# EPA Larnaca and EPA Larnaca FC(Idx=1394) are 0.880000 similar and from the same country Cyprus.
# EPA Larnaca and EPA Larnaca FC(Idx=1395) are 0.880000 similar and from the same country Cyprus.
# Eintracht Braunschweig and Eintracht Bad Kreuznach(Idx=1418) are 0.666667 similar and from the same country Germany.
# Eintracht Braunschweig and Eintracht Braunschweig(Idx=1419) are 1.000000 similar and from the same country Germany.
# Eintracht Braunschweig and Eintracht Frankfurt(Idx=1420) are 0.634146 similar and from the same country Germany.
# Eintracht Braunschweig and FC Eintracht Bamberg(Idx=1664) are 0.619048 similar and from the same country Germany.
# Eintracht Braunschweig and FC Eintracht Rheine(Idx=1666) are 0.634146 similar and from the same country Germany.
# Elfsborg and IF Elfsborg(Idx=2386) are 0.842105 similar and from the same country Sweden.
# Esbjerg fB and Esbjerg fB(Idx=1463) are 1.000000 similar and from the same country Denmark.
# Etar Tarnovo and FC Etar 1924 Veliko Tarnovo(Idx=1674) are 0.615385 similar and from the same country Bulgaria.
# F91 Dudelange and F91 Dudelange(Idx=1555) are 1.000000 similar and from the same country Luxembourg.
# FBK Kaunas and FBK Kaunas(Idx=1561) are 1.000000 similar and from the same country Lithuania.
# FBK Kaunas and FK Ekranas(Idx=1978) are 0.700000 similar and from the same country Lithuania.
# FC Aarau and FC Aarau(Idx=1564) are 1.000000 similar and from the same country Switzerland.
# FC Ararat and FC Ararat Yerevan(Idx=1580) are 0.692308 similar and from the same country Armenia.
# FC Ararat and FC Banants(Idx=1596) are 0.631579 similar and from the same country Armenia.
# FC Carl Zeiss Jena and FC Carl Zeiss Jena(Idx=1624) are 1.000000 similar and from the same country Germany.
# FC Jazz and FC Jazz(Idx=1713) are 1.000000 similar and from the same country Finland.
# FC Kuusysi and FC Kuusysi(Idx=1732) are 1.000000 similar and from the same country Finland.
# FC La Chaux-de-Fonds and FC La Chaux-de-Fonds(Idx=1735) are 1.000000 similar and from the same country Switzerland.
# FC Luzern and FC Locarno(Idx=1743) are 0.631579 similar and from the same country Switzerland.
# FC Luzern and FC Lugano(Idx=1748) are 0.666667 similar and from the same country Switzerland.
# FC Luzern and FC Luzern(Idx=1751) are 1.000000 similar and from the same country Switzerland.
# FC Luzern and FC Thun(Idx=1871) are 0.625000 similar and from the same country Switzerland.
# FC Norma Tallinn and FC Flora Tallinn(Idx=1678) are 0.875000 similar and from the same country Estonia.
# FC Norma Tallinn and FC Levadia Tallinn(Idx=1740) are 0.705882 similar and from the same country Estonia.
# FC Norma Tallinn and FC TVMK Tallinn(Idx=1867) are 0.709677 similar and from the same country Estonia.
# FC Politehnica Timisoara and ACS Poli Timișoara(Idx=129) are 0.714286 similar and from the same country Romania.
# FC Politehnica Timisoara and FC Politehnica Iaşi(Idx=1799) are 0.744186 similar and from the same country Romania.
# FC Politehnica Timisoara and FC Politehnica Timişoara(Idx=1800) are 0.958333 similar and from the same country Romania.
# FC Politehnica Timisoara and FC Ripensia Timișoara(Idx=1809) are 0.755556 similar and from the same country Romania.
# FC Porto and F.C. Porto(Idx=1537) are 0.888889 similar and from the same country Portugal.
# FC Reipas Lahti and FC Lahti(Idx=1736) are 0.695652 similar and from the same country Finland.
# FC Santa Coloma and FC Santa Coloma(Idx=1823) are 1.000000 similar and from the same country Andorra.
# FC Santa Coloma and UE Santa Coloma(Idx=4104) are 0.866667 similar and from the same country Andorra.
# FC Slavia Mozyr and FC Savit Mogilev(Idx=1825) are 0.645161 similar and from the same country Belarus.
# FC Universitatea Craiova and FC Cetatea Suceava(Idx=1627) are 0.619048 similar and from the same country Romania.
# FC Universitatea Craiova and FC Universitatea Cluj(Idx=1893) are 0.800000 similar and from the same country Romania.
# FC Universitatea Craiova and FC Universitatea Craiova(Idx=1894) are 1.000000 similar and from the same country Romania.
# FC Yerevan and FC Arabkir Yerevan(Idx=1579) are 0.714286 similar and from the same country Armenia.
# FC Yerevan and FC Ararat Yerevan(Idx=1580) are 0.740741 similar and from the same country Armenia.
# FC Yerevan and FC Van Yerevan(Idx=1898) are 0.833333 similar and from the same country Armenia.
# FC Yerevan and FC Yerevan(Idx=1921) are 1.000000 similar and from the same country Armenia.
# FC Yerevan and SC Nairi Yerevan(Idx=3527) are 0.692308 similar and from the same country Armenia.
# FC Zurich and FC Zürich(Idx=1933) are 0.888889 similar and from the same country Switzerland.
# FK Ekranas and FBK Kaunas(Idx=1561) are 0.700000 similar and from the same country Lithuania.
# FK Ekranas and FK Ekranas(Idx=1978) are 1.000000 similar and from the same country Lithuania.
# FK Inter Bratislava and FK Inter Bratislava(Idx=1986) are 1.000000 similar and from the same country Slovakia.
# FK Inter Bratislava and ŠK Slovan Bratislava(Idx=4431) are 0.717949 similar and from the same country Slovakia.
# FK Kareda Kaunas and FBK Kaunas(Idx=1561) are 0.692308 similar and from the same country Lithuania.
# FK Leotar and FK Velež Mostar(Idx=2053) are 0.666667 similar and from the same country Bosnia and Herzegovina.
# FK Mogren and FK Lovćen(Idx=2000) are 0.666667 similar and from the same country Montenegro.
# FK Mogren and FK Mogren(Idx=2008) are 1.000000 similar and from the same country Montenegro.
# FK Mogren and FK Mornar(Idx=2009) are 0.777778 similar and from the same country Montenegro.
# FK Obilic and FK Obilić(Idx=2015) are 0.888889 similar and from the same country Serbia.
# FK Partizani Tirana and Partizani Tirana(Idx=3181) are 0.914286 similar and from the same country Albania.
# FK Rudar Pljevlja and FK Rudar Pljevlja(Idx=2033) are 1.000000 similar and from the same country Montenegro.
# FK Sarajevo and F.K. Sarajevo(Idx=1552) are 0.916667 similar and from the same country Bosnia and Herzegovina.
# FK Sarajevo and F.K. Željezničar Sarajevo(Idx=1554) are 0.611111 similar and from the same country Bosnia and Herzegovina.
# FK Vllaznia and KS Vllaznia Shkodër(Idx=2520) are 0.666667 similar and from the same country Albania.
# FK Zalgiris Vilnius and FK REO Vilnius(Idx=2027) are 0.666667 similar and from the same country Lithuania.
# FK Zalgiris Vilnius and VMFD Žalgiris Vilnius(Idx=4192) are 0.850000 similar and from the same country Lithuania.
# FK Zeta and FK Berane(Idx=1960) are 0.625000 similar and from the same country Montenegro.
# FK Zeta and OFK Petrovac(Idx=3025) are 0.631579 similar and from the same country Montenegro.
# Fenerbahce and Fenerbahçe S.K.(Idx=2079) are 0.720000 similar and from the same country Turkey.
# Ferencvaros and Ferencvárosi TC(Idx=2080) are 0.769231 similar and from the same country Hungary.
# Feyenoord and Feyenoord(Idx=2084) are 1.000000 similar and from the same country Netherlands.
# Flora Tallinn and FC Flora Tallinn(Idx=1678) are 0.896552 similar and from the same country Estonia.
# Flora Tallinn and FC Levadia Tallinn(Idx=1740) are 0.645161 similar and from the same country Estonia.
# Flora Tallinn and FC TVMK Tallinn(Idx=1867) are 0.642857 similar and from the same country Estonia.
# Galatasaray and Galatasaray S.K.(Idx=2152) are 0.814815 similar and from the same country Turkey.
# Galatasaray and Malatyaspor(Idx=2762) are 0.636364 similar and from the same country Turkey.
# Girondins Bordeaux and F.C. Girondins de Bordeaux(Idx=1525) are 0.818182 similar and from the same country France.
# Gomel and FC Gomel(Idx=1685) are 0.769231 similar and from the same country Belarus.
# Gornik Zabrze and Górnik Zabrze(Idx=2250) are 0.923077 similar and from the same country Poland.
# Grasshoppers Zurich and Grasshopper Club Zürich(Idx=2209) are 0.809524 similar and from the same country Switzerland.
# Grazer AK and Grazer AK(Idx=2211) are 1.000000 similar and from the same country Austria.
# Grevenmacher and CS Grevenmacher(Idx=859) are 0.888889 similar and from the same country Luxembourg.
# Grevenmacher and CS Grevenmacher(Idx=860) are 0.888889 similar and from the same country Luxembourg.
# Gyori ETO and Győri ETO FC(Idx=2249) are 0.761905 similar and from the same country Hungary.
# HB Koge and HB Køge(Idx=2258) are 0.857143 similar and from the same country Denmark.
# HNK Gorica and HNK Gorica(Idx=2263) are 1.000000 similar and from the same country Croatia.
# HNK Gorica and HŠK Concordia(Idx=2382) are 0.608696 similar and from the same country Croatia.
# HNK Gorica and NK Koprivnica(Idx=2922) are 0.695652 similar and from the same country Croatia.
# HNK Rijeka and H.N.K. Rijeka(Idx=2256) are 0.869565 similar and from the same country Croatia.
# HNK Rijeka and HNK Šibenik(Idx=2265) are 0.666667 similar and from the same country Croatia.
# HNK Rijeka and NK Osijek(Idx=2930) are 0.736842 similar and from the same country Croatia.
# HSK Zrinjski Mostar and HŠK Zrinjski Mostar(Idx=2383) are 0.947368 similar and from the same country Bosnia and Herzegovina.
# Hajduk Split and H.N.K. Hajduk Split(Idx=2255) are 0.774194 similar and from the same country Croatia.
# Halmstads BK and Halmstads BK(Idx=2277) are 1.000000 similar and from the same country Sweden.
# Halmstads BK and Karlstad BK(Idx=2534) are 0.782609 similar and from the same country Sweden.
# Hamburger SV and Hamburger SV(Idx=2279) are 1.000000 similar and from the same country Germany.
# Hamburger SV and Hamburger SV (women)(Idx=2280) are 0.750000 similar and from the same country Germany.
# Hammarby and Hammarby Fotboll(Idx=2284) are 0.666667 similar and from the same country Sweden.
# Hammarby and Hammarby IF DFF(Idx=2285) are 0.695652 similar and from the same country Sweden.
# Hammarby and Hammarby Talang FF(Idx=2286) are 0.615385 similar and from the same country Sweden.
# Hamrun Spartans and Ħamrun Spartans F.C.(Idx=4424) are 0.800000 similar and from the same country Malta.
# Hansa Rostock and F.C. Hansa Rostock(Idx=1527) are 0.838710 similar and from the same country Germany.
# Hapoel Haifa and Hapoel Haifa F.C.(Idx=2297) are 0.827586 similar and from the same country Israel.
# Hapoel Ironi Kiryat Shmona and Hapoel Ironi Kiryat Shmona F.C.(Idx=2298) are 0.912281 similar and from the same country Israel.
# Hapoel Ironi Kiryat Shmona and Hapoel Kiryat Shmona F.C.(Idx=2302) are 0.784314 similar and from the same country Israel.
# Hapoel Tel Aviv and Hapoel Acre A.F.C.(Idx=2294) are 0.606061 similar and from the same country Israel.
# Hapoel Tel Aviv and Hapoel Tel Aviv F.C.(Idx=2307) are 0.857143 similar and from the same country Israel.
# Hellas Verona and Hellas Verona F.C.(Idx=2326) are 0.838710 similar and from the same country Italy.
# Helsingborgs IF and Helsingborgs IF(Idx=2328) are 1.000000 similar and from the same country Sweden.
# Helsingborgs IF and Trelleborgs FF(Idx=4044) are 0.620690 similar and from the same country Sweden.
# Hertha BSC and Hertha BSC(Idx=2335) are 1.000000 similar and from the same country Germany.
# Hibernians and Hibernians F.C.(Idx=2338) are 0.800000 similar and from the same country Malta.
# Hvidovre IF and Hvidovre IF(Idx=2375) are 1.000000 similar and from the same country Denmark.
# IB Vestmannaeyja and Íþróttabandalag Vestmannaeyja(Idx=4412) are 0.622222 similar and from the same country Iceland.
# IFK Goteborg and AIK Fotboll(Idx=160) are 0.608696 similar and from the same country Sweden.
# IFK Goteborg and IF Elfsborg(Idx=2386) are 0.608696 similar and from the same country Sweden.
# IFK Goteborg and IFK Göteborg(Idx=2389) are 0.916667 similar and from the same country Sweden.
# IFK Goteborg and IFK Trelleborg(Idx=2393) are 0.692308 similar and from the same country Sweden.
# IFK Malmo and IFK Malmö(Idx=2390) are 0.888889 similar and from the same country Sweden.
# IFK Norrkoping and IFK Norrköping(Idx=2392) are 0.928571 similar and from the same country Sweden.
# Inter Baku PIK and Inter Baku PFC(Idx=2427) are 0.857143 similar and from the same country Azerbaijan.
# Inter Turku and FC Inter Turku(Idx=1708) are 0.880000 similar and from the same country Finland.
# Irtysh Pavlodar and FC Irtysh Pavlodar(Idx=1709) are 0.909091 similar and from the same country Kazakhstan.
# Juventus and Juventus F.C.(Idx=2487) are 0.761905 similar and from the same country Italy.
# KF Tirana and KF Tirana(Idx=2510) are 1.000000 similar and from the same country Albania.
# KF Tirana and KF Tirana B(Idx=2511) are 0.900000 similar and from the same country Albania.
# KF Tirana and KS Dinamo Tirana(Idx=2516) are 0.640000 similar and from the same country Albania.
# KF Tirana and Tirana AS(Idx=4012) are 0.666667 similar and from the same country Albania.
# KRC Genk and K.R.C. Genk(Idx=2495) are 0.842105 similar and from the same country Belgium.
# KS Elbasani and KS Elbasani(Idx=2517) are 1.000000 similar and from the same country Albania.
# KSK Beveren and K.S.K. Beveren(Idx=2498) are 0.880000 similar and from the same country Belgium.
# KV Mechelen and K.R.C. Mechelen(Idx=2496) are 0.769231 similar and from the same country Belgium.
# KV Mechelen and KV Mechelen(Idx=2523) are 1.000000 similar and from the same country Belgium.
# Kairat and FC Kairat(Idx=1715) are 0.800000 similar and from the same country Kazakhstan.
# Kaiserslautern and 1. FC Kaiserslautern(Idx=35) are 0.823529 similar and from the same country Germany.
# Kalmar FF and Dalkurd FF(Idx=1244) are 0.631579 similar and from the same country Sweden.
# Kalmar FF and Kalmar FF(Idx=2527) are 1.000000 similar and from the same country Sweden.
# Kalmar FF and Malmö FF(Idx=2765) are 0.705882 similar and from the same country Sweden.
# Khazar Lankaran and FK Khazar Lankaran(Idx=1994) are 0.909091 similar and from the same country Azerbaijan.
# Kispesti Honved and Budapest Honvéd FC(Idx=717) are 0.606061 similar and from the same country Hungary.
# Koper and FC Koper(Idx=1725) are 0.769231 similar and from the same country Slovenia.
# Kosice and MFK Košice(Idx=2723) are 0.625000 similar and from the same country Slovakia.
# Kuopion PS and Kuopion Palloseura(Idx=2605) are 0.642857 similar and from the same country Finland.
# Lantana Tallinn and FC Levadia Tallinn(Idx=1740) are 0.666667 similar and from the same country Estonia.
# Lausanne Sports and FC Lausanne-Sport(Idx=1737) are 0.812500 similar and from the same country Switzerland.
# Lazio and S.S. Lazio(Idx=3497) are 0.666667 similar and from the same country Italy.
# Lech Poznan and Lech Poznań(Idx=2628) are 0.909091 similar and from the same country Poland.
# Legia Warsaw and KP Legia Warsaw(Idx=2514) are 0.888889 similar and from the same country Poland.
# Legia Warsaw and Polonia Warsaw(Idx=3275) are 0.692308 similar and from the same country Poland.
# Levski Sofia and PFC Levski Sofia(Idx=3118) are 0.857143 similar and from the same country Bulgaria.
# Lierse and Lierse S.K.(Idx=2651) are 0.705882 similar and from the same country Belgium.
# Lille OSC and Lille O.S.C.(Idx=2657) are 0.857143 similar and from the same country France.
# Limerick FC and Limerick F.C.(Idx=2660) are 0.916667 similar and from the same country Ireland.
# Linzer ASK and Grazer AK(Idx=2211) are 0.631579 similar and from the same country Austria.
# Lokomotiv Moskva and FC Lokomotiv Moscow(Idx=1744) are 0.742857 similar and from the same country Russia.
# Lokomotiv Sofia and PFC Lokomotiv Mezdra(Idx=3120) are 0.628571 similar and from the same country Bulgaria.
# Lokomotiv Sofia and PFC Lokomotiv Plovdiv(Idx=3121) are 0.666667 similar and from the same country Bulgaria.
# Lokomotiv Sofia and PFC Lokomotiv Sofia(Idx=3122) are 0.882353 similar and from the same country Bulgaria.
# Lugano and FC Lugano(Idx=1748) are 0.800000 similar and from the same country Switzerland.
# Lusitanos and FC Lusitanos(Idx=1749) are 0.857143 similar and from the same country Andorra.
# Lyngby BK and Lyngby Boldklub(Idx=2709) are 0.666667 similar and from the same country Denmark.
# MFK Ruzomberok and MFK Ružomberok(Idx=2724) are 0.928571 similar and from the same country Slovakia.
# MSK Zilina and MŠK Žilina(Idx=2898) are 0.800000 similar and from the same country Slovakia.
# MYPA and MYPA(Idx=2738) are 1.000000 similar and from the same country Finland.
# Maccabi Haifa and Maccabi Haifa F.C.(Idx=2740) are 0.838710 similar and from the same country Israel.
# Maccabi Haifa and Maccabi Netanya F.C.(Idx=2744) are 0.606061 similar and from the same country Israel.
# Maccabi Tel Aviv and Maccabi Tel Aviv F.C.(Idx=2746) are 0.864865 similar and from the same country Israel.
# Magdeburg and 1. FC Magdeburg(Idx=38) are 0.750000 similar and from the same country Germany.
# Magdeburg and Magdeburger FFC(Idx=2752) are 0.750000 similar and from the same country Germany.
# Malaga CF and Granada CF(Idx=2208) are 0.631579 similar and from the same country Spain.
# Malaga CF and Málaga C.F.(Idx=2894) are 0.800000 similar and from the same country Spain.
# Malaga CF and Málaga CF(Idx=2895) are 0.888889 similar and from the same country Spain.
# Malaga CF and Talavera CF(Idx=3966) are 0.700000 similar and from the same country Spain.
# Malmo FF and Kalmar FF(Idx=2527) are 0.705882 similar and from the same country Sweden.
# Malmo FF and Malmö FF(Idx=2765) are 0.875000 similar and from the same country Sweden.
# Marsaxlokk and Marsaxlokk F.C.(Idx=2793) are 0.800000 similar and from the same country Malta.
# Metalurgi Rustavi and FC Metalurgi Rustavi(Idx=1758) are 0.918919 similar and from the same country Georgia.
# Metz and F.C. Metz(Idx=1530) are 0.615385 similar and from the same country France.
# Midtjylland and FC Midtjylland(Idx=1761) are 0.880000 similar and from the same country Denmark.
# Mlada Boleslav and FK Mladá Boleslav(Idx=2007) are 0.838710 similar and from the same country Czech Republic.
# NK Domzale and NK Domžale(Idx=2910) are 0.900000 similar and from the same country Slovenia.
# NK Maribor and NK Branik Maribor(Idx=2906) are 0.740741 similar and from the same country Slovenia.
# NK Maribor and NK Maribor(Idx=2925) are 1.000000 similar and from the same country Slovenia.
# NK Zagreb and N.K. Dinamo Zagreb(Idx=2900) are 0.666667 similar and from the same country Croatia.
# NK Zagreb and N.K. Zagreb(Idx=2901) are 0.900000 similar and from the same country Croatia.
# NK Zagreb and NK Varteks(Idx=2935) are 0.631579 similar and from the same country Croatia.
# NK Zagreb and NK Zadar(Idx=2936) are 0.705882 similar and from the same country Croatia.
# Nantes and F.C. Nantes(Idx=1532) are 0.705882 similar and from the same country France.
# Neftchi PFC Baku and FC Baku(Idx=1594) are 0.608696 similar and from the same country Azerbaijan.
# Neftchi PFC Baku and Neftchi Baku PFC(Idx=2964) are 0.750000 similar and from the same country Azerbaijan.
# Neuchatel Xamax FC and Neuchâtel Xamax(Idx=2967) are 0.848485 similar and from the same country Switzerland.
# Nomme Kalju and Nõmme Kalju FC(Idx=3015) are 0.800000 similar and from the same country Estonia.
# Nordsjaelland and FC Nordsjælland(Idx=1774) are 0.785714 similar and from the same country Denmark.
# Nurnberg and 1. FC Nürnberg(Idx=39) are 0.636364 similar and from the same country Germany.
# OGC Nice and O.G.C. Nice(Idx=3020) are 0.842105 similar and from the same country France.
# OPS Oulu and AC Oulu(Idx=121) are 0.666667 similar and from the same country Finland.
# Odense BK and Odense Boldklub(Idx=3035) are 0.666667 similar and from the same country Denmark.
# Olimpija Ljubljana and NK Olimpija Ljubljana(Idx=2929) are 0.923077 similar and from the same country Slovenia.
# Olympiacos and Olympiacos F.C.(Idx=3041) are 0.800000 similar and from the same country Greece.
# Olympique Lyon and Nîmes Olympique(Idx=3014) are 0.620690 similar and from the same country France.
# Olympique Lyon and Olympique Alès(Idx=3048) are 0.714286 similar and from the same country France.
# Olympique Lyon and Olympique Lyonnais(Idx=3050) are 0.875000 similar and from the same country France.
# Olympique Lyon and Olympique Lyonnais(Idx=3051) are 0.875000 similar and from the same country France.
# Olympique Marseille and Olympique Alès(Idx=3048) are 0.666667 similar and from the same country France.
# Olympique Marseille and Olympique Lyonnais(Idx=3050) are 0.648649 similar and from the same country France.
# Olympique Marseille and Olympique Lyonnais(Idx=3051) are 0.648649 similar and from the same country France.
# Olympique Marseille and Olympique Saint-Maurice(Idx=3053) are 0.666667 similar and from the same country France.
# Olympique Marseille and Olympique de Marseille(Idx=3054) are 0.926829 similar and from the same country France.
# Omonia Nicosia and Gaydzak Nicosia(Idx=2165) are 0.620690 similar and from the same country Cyprus.
# Omonia Nicosia and Olympiakos Nicosia FC(Idx=3042) are 0.685714 similar and from the same country Cyprus.
# Omonia Nicosia and Omonia Ormideia(Idx=3064) are 0.689655 similar and from the same country Cyprus.
# Omonia Nicosia and Orfeas Nicosia(Idx=3077) are 0.714286 similar and from the same country Cyprus.
# Omonia Nicosia and Orfeas Nicosia(Idx=3078) are 0.714286 similar and from the same country Cyprus.
# Orgryte IS and Örgryte IS(Idx=4415) are 0.900000 similar and from the same country Sweden.
# Osasuna and CAO Osasuna(Idx=796) are 0.777778 similar and from the same country Spain.
# Osters IF and Östers IF(Idx=4416) are 0.888889 similar and from the same country Sweden.
# Osters IF and Östersunds DFF(Idx=4417) are 0.608696 similar and from the same country Sweden.
# Osters IF and Östersunds FK(Idx=4418) are 0.636364 similar and from the same country Sweden.
# Otelul Galati and FC Oțelul Galați(Idx=1788) are 0.758621 similar and from the same country Romania.
# PAOK and PAOK FC(Idx=3103) are 0.727273 similar and from the same country Greece.
# PFC Litex Lovech and PFC Litex Lovech(Idx=3119) are 1.000000 similar and from the same country Bulgaria.
# PFC Lokomotiv Plovdiv and FC Spartak Plovdiv(Idx=1852) are 0.615385 similar and from the same country Bulgaria.
# PFC Lokomotiv Plovdiv and PFC Botev Plovdiv(Idx=3111) are 0.789474 similar and from the same country Bulgaria.
# PFC Lokomotiv Plovdiv and PFC Lokomotiv Mezdra(Idx=3120) are 0.731707 similar and from the same country Bulgaria.
# PFC Lokomotiv Plovdiv and PFC Lokomotiv Plovdiv(Idx=3121) are 1.000000 similar and from the same country Bulgaria.
# PFC Lokomotiv Plovdiv and PFC Lokomotiv Sofia(Idx=3122) are 0.800000 similar and from the same country Bulgaria.
# PFC Ludogorets Razgrad and PFC Ludogorets Razgrad(Idx=3123) are 1.000000 similar and from the same country Bulgaria.
# PFC Slavia Sofia and PFC Akademik Sofia(Idx=3108) are 0.705882 similar and from the same country Bulgaria.
# PFC Slavia Sofia and PFC CSKA - Sofia(Idx=3112) are 0.687500 similar and from the same country Bulgaria.
# PFC Slavia Sofia and PFC Levski Sofia(Idx=3118) are 0.750000 similar and from the same country Bulgaria.
# PFC Slavia Sofia and PFC Lokomotiv Sofia(Idx=3122) are 0.628571 similar and from the same country Bulgaria.
# PFC Slavia Sofia and PFC Slavia Sofia(Idx=3131) are 1.000000 similar and from the same country Bulgaria.
# PSV Eindhoven and FC Eindhoven(Idx=1663) are 0.800000 similar and from the same country Netherlands.
# PSV Eindhoven and PSV Eindhoven(Idx=3147) are 1.000000 similar and from the same country Netherlands.
# Pacos de Ferreira and F.C. Paços de Ferreira(Idx=1535) are 0.820513 similar and from the same country Portugal.
# Panathinaikos and Panathinaikos F.C.(Idx=3163) are 0.838710 similar and from the same country Greece.
# Paris Saint-Germain and Paris Saint-Germain(Idx=3175) are 1.000000 similar and from the same country France.
# Paris Saint-Germain and Paris Saint-Germain F.C.(Idx=3176) are 0.883721 similar and from the same country France.
# Petrolul Ploiesti and FC Petrolul Ploiești(Idx=1794) are 0.864865 similar and from the same country Romania.
# Petrolul Ploiesti and Prahova Ploiești(Idx=3297) are 0.666667 similar and from the same country Romania.
# Petrzalka Akademia and FC Petržalka akadémia(Idx=1796) are 0.769231 similar and from the same country Slovakia.
# Pezoporikos Larnaca and Pezoporikos Larnaca FC(Idx=3232) are 0.926829 similar and from the same country Cyprus.
# Pezoporikos Larnaca and Pezoporikos Larnaca FC(Idx=3233) are 0.926829 similar and from the same country Cyprus.
# Polonia Bytom and Polonia Bytom(Idx=3273) are 1.000000 similar and from the same country Poland.
# Polonia Warszawa and KP Legia Warsaw(Idx=2514) are 0.645161 similar and from the same country Poland.
# Polonia Warszawa and Polonia Warsaw(Idx=3275) are 0.933333 similar and from the same country Poland.
# Pyunik and FC Pyunik(Idx=1804) are 0.800000 similar and from the same country Armenia.
# RC Lens and R.C. Lens(Idx=3333) are 0.875000 similar and from the same country France.
# RC Strasbourg and RC Strasbourg(Idx=3341) are 1.000000 similar and from the same country France.
# RCD Mallorca and CA Marbella(Idx=794) are 0.608696 similar and from the same country Spain.
# RCD Mallorca and RCD Mallorca(Idx=3347) are 1.000000 similar and from the same country Spain.
# RCD Mallorca and UD Marbella(Idx=4094) are 0.608696 similar and from the same country Spain.
# RSC Anderlecht and R.S.C. Anderlecht(Idx=3336) are 0.903226 similar and from the same country Belgium.
# Rabat Ajax and Rabat Ajax F.C.(Idx=3353) are 0.800000 similar and from the same country Malta.
# Ranger's and FC Rànger's(Idx=1819) are 0.736842 similar and from the same country Andorra.
# Rapid Bucuresti and FC Rapid București(Idx=1805) are 0.848485 similar and from the same country Romania.
# Rapid Bucuresti and Victoria București(Idx=4255) are 0.606061 similar and from the same country Romania.
# Rapid Wien and SK Rapid Wien(Idx=3567) are 0.869565 similar and from the same country Austria.
# Real Betis and Real Avilés(Idx=3379) are 0.666667 similar and from the same country Spain.
# Real Betis and Real Betis B(Idx=3380) are 0.909091 similar and from the same country Spain.
# Real Betis and Real Betis Balompié(Idx=3381) are 0.689655 similar and from the same country Spain.
# Real Madrid and Atlético Madrid(Idx=514) are 0.615385 similar and from the same country Spain.
# Real Madrid and Real Madrid C(Idx=3390) are 0.916667 similar and from the same country Spain.
# Real Madrid and Real Madrid C.F.(Idx=3391) are 0.814815 similar and from the same country Spain.
# Real Madrid and Real Madrid FC(Idx=3392) are 0.880000 similar and from the same country Spain.
# Real Madrid and Real Murcia(Idx=3393) are 0.636364 similar and from the same country Spain.
# Real Madrid and Real Valladolid(Idx=3403) are 0.692308 similar and from the same country Spain.
# Real Madrid and Real Valladolid(Idx=3404) are 0.692308 similar and from the same country Spain.
# Real Madrid and Real Valladolid B(Idx=3405) are 0.642857 similar and from the same country Spain.
# Real Sociedad and Real Murcia(Idx=3393) are 0.666667 similar and from the same country Spain.
# Real Sociedad and Real Sociedad(Idx=3398) are 1.000000 similar and from the same country Spain.
# Real Sociedad and Real Sociedad(Idx=3399) are 1.000000 similar and from the same country Spain.
# Real Sociedad and Real Sociedad B(Idx=3400) are 0.928571 similar and from the same country Spain.
# Rot-Weiss Essen and Rot Weiss Ahlen(Idx=3452) are 0.733333 similar and from the same country Germany.
# Rot-Weiss Essen and Rot-Weiss Essen(Idx=3453) are 1.000000 similar and from the same country Germany.
# Rot-Weiss Essen and Rot-Weiss Frankfurt(Idx=3454) are 0.647059 similar and from the same country Germany.
# Rot-Weiss Essen and Rot-Weiß Oberhausen(Idx=3456) are 0.647059 similar and from the same country Germany.
# Rot-Weiss Essen and Schwarz-Weiß Essen(Idx=3691) are 0.606061 similar and from the same country Germany.
# Rubin Kazan and Rubin Kazan(Idx=3464) are 1.000000 similar and from the same country Russia.
# Ruch Chorzow and Ruch Chorzów(Idx=3465) are 0.916667 similar and from the same country Poland.
# SC Motor Jena and SV Motor Altenburg(Idx=3596) are 0.645161 similar and from the same country Germany.
# SC Motor Jena and SV Schott Jena(Idx=3604) are 0.666667 similar and from the same country Germany.
# SK Slovan Bratislava and FK Inter Bratislava(Idx=1986) are 0.717949 similar and from the same country Slovakia.
# SK Slovan Bratislava and ŠK Slovan Bratislava(Idx=4431) are 0.950000 similar and from the same country Slovakia.
# SL Benfica and S.L. Benfica(Idx=3486) are 0.909091 similar and from the same country Portugal.
# SL Benfica and S.L. Benfica(Idx=3487) are 0.909091 similar and from the same country Portugal.
# SL Benfica and S.L. Benfica(Idx=3488) are 0.909091 similar and from the same country Portugal.
# SL Benfica and S.L. Benfica B(Idx=3489) are 0.833333 similar and from the same country Portugal.
# SL Benfica and S.L. Benfica Juniors(Idx=3490) are 0.666667 similar and from the same country Portugal.
# SSC Napoli and Napoli(Idx=2954) are 0.750000 similar and from the same country Italy.
# SSW Innsbruck and FC Wacker Innsbruck(Idx=1915) are 0.687500 similar and from the same country Austria.
# Saarbrucken and 1. FC Saarbrücken(Idx=41) are 0.714286 similar and from the same country Germany.
# Saarbrucken and 1. FC Saarbrücken(Idx=42) are 0.714286 similar and from the same country Germany.
# Saarbrucken and SV Saar 05 Saarbrücken(Idx=3602) are 0.606061 similar and from the same country Germany.
# Schalke 04 and FC Schalke 04(Idx=1828) are 0.869565 similar and from the same country Germany.
# Servette Geneve and Servette FC(Idx=3715) are 0.692308 similar and from the same country Switzerland.
# Sevilla and Sevilla FC(Idx=3718) are 0.823529 similar and from the same country Spain.
# Shakhter Karagandy and FC Shakhter Karagandy(Idx=1833) are 0.923077 similar and from the same country Kazakhstan.
# Shamrock Rovers and Shamrock Rovers F.C.(Idx=3730) are 0.857143 similar and from the same country Ireland.
# Shelbourne and Shelbourne F.C.(Idx=3742) are 0.800000 similar and from the same country Ireland.
# Shirak and Shirak FC(Idx=3751) are 0.800000 similar and from the same country Armenia.
# Silkeborg IF and Silkeborg IF(Idx=3759) are 1.000000 similar and from the same country Denmark.
# Silkeborg IF and Viborg FF(Idx=4253) are 0.666667 similar and from the same country Denmark.
# Sion and FC Sion(Idx=1843) are 0.727273 similar and from the same country Switzerland.
# Sioni Bolnisi and FC Sioni Bolnisi(Idx=1844) are 0.896552 similar and from the same country Georgia.
# Sivasspor and Manisaspor(Idx=2776) are 0.631579 similar and from the same country Turkey.
# Sivasspor and Samsunspor(Idx=3634) are 0.736842 similar and from the same country Turkey.
# Sivasspor and Sivasspor(Idx=3768) are 1.000000 similar and from the same country Turkey.
# Skenderbeu Korce and KF Skënderbeu Korçë(Idx=2507) are 0.742857 similar and from the same country Albania.
# Skonto and Skonto FC(Idx=3773) are 0.800000 similar and from the same country Latvia.
# Slask Wroclaw and Śląsk Wrocław(Idx=4428) are 0.769231 similar and from the same country Poland.
# Slavia Praha and SK Slavia Prague(Idx=3569) are 0.714286 similar and from the same country Czech Republic.
# Sliema Wanderers and Sliema Wanderers F.C.(Idx=3775) are 0.864865 similar and from the same country Malta.
# Sligo Rovers and Sligo Rovers F.C.(Idx=3776) are 0.827586 similar and from the same country Ireland.
# Slovan Liberec and FC Slovan Liberec(Idx=1845) are 0.903226 similar and from the same country Czech Republic.
# Sparta Praha and AC Sparta Prague(Idx=123) are 0.714286 similar and from the same country Czech Republic.
# Sparta Rotterdam and Sparta Rotterdam(Idx=3813) are 1.000000 similar and from the same country Netherlands.
# Spartak Moskva and Spartak Moscow(Idx=3814) are 0.785714 similar and from the same country Russia.
# Spartak Plovdiv and FC Spartak Plovdiv(Idx=1852) are 0.909091 similar and from the same country Bulgaria.
# Spartak TAZ Trnava and FC Spartak Trnava(Idx=1854) are 0.800000 similar and from the same country Slovakia.
# Spartak TAZ Trnava and Spartak Myjava(Idx=3815) are 0.687500 similar and from the same country Slovakia.
# St Patrick's Athletic and St Patrick's Athletic F.C.(Idx=3862) are 0.893617 similar and from the same country Ireland.
# St. Gallen and FC St. Gallen(Idx=1857) are 0.869565 similar and from the same country Switzerland.
# Stade Dudelange and F91 Dudelange(Idx=1555) are 0.714286 similar and from the same country Luxembourg.
# Stade Reims and Stade Brestois 29(Idx=3872) are 0.642857 similar and from the same country France.
# Stade Reims and Stade Lavallois(Idx=3874) are 0.615385 similar and from the same country France.
# Stade Reims and Stade Rennais F.C.(Idx=3877) are 0.689655 similar and from the same country France.
# Stade Reims and Stade de Reims(Idx=3881) are 0.880000 similar and from the same country France.
# Stal Mielec and Stal Mielec(Idx=3883) are 1.000000 similar and from the same country Poland.
# Standard Liege and Standard Liège(Idx=3885) are 0.928571 similar and from the same country Belgium.
# Steaua Bucuresti and CS Juventus București(Idx=862) are 0.648649 similar and from the same country Romania.
# Steaua Bucuresti and FC Steaua Bucharest(Idx=1862) are 0.800000 similar and from the same country Romania.
# Steaua Bucuresti and FC Steaua Bucharest(Idx=1863) are 0.800000 similar and from the same country Romania.
# Steaua Bucuresti and Venus București(Idx=4232) are 0.709677 similar and from the same country Romania.
# Steaua Bucuresti and Victoria București(Idx=4255) are 0.647059 similar and from the same country Romania.
# Sturm Graz and S.K. Sturm Graz(Idx=3485) are 0.800000 similar and from the same country Austria.
# Sutjeska Niksic and FK Sutjeska Nikšić(Idx=2046) are 0.787879 similar and from the same country Montenegro.
# TJ Vitkovice and FC Vítkovice(Idx=1912) are 0.750000 similar and from the same country Czech Republic.
# TJ Vitkovice and FC Vítkovice(Idx=1913) are 0.750000 similar and from the same country Czech Republic.
# TSV 1860 Munchen and TSV 1860 München(Idx=3952) are 0.937500 similar and from the same country Germany.
# TSV 1860 Munchen and TSV 1860 München II(Idx=3953) are 0.857143 similar and from the same country Germany.
# TSV 1860 Munchen and TSV 1860 Rosenheim(Idx=3954) are 0.705882 similar and from the same country Germany.
# Tampere United and Tampere United(Idx=3972) are 1.000000 similar and from the same country Finland.
# Tampere United and Åland United(Idx=4403) are 0.615385 similar and from the same country Finland.
# Teplice and FK Teplice(Idx=2048) are 0.823529 similar and from the same country Czech Republic.
# Thun and FC Thun(Idx=1871) are 0.727273 similar and from the same country Switzerland.
# Tobol and FC Tobol(Idx=1873) are 0.769231 similar and from the same country Kazakhstan.
# Torpedo Kutaisi and FC Torpedo Kutaisi(Idx=1876) are 0.909091 similar and from the same country Georgia.
# Torpedo Moskva and FC Torpedo Moscow(Idx=1877) are 0.709677 similar and from the same country Russia.
# Torpedo Moskva and FC Torpedo-ZIL Moscow(Idx=1882) are 0.628571 similar and from the same country Russia.
# Toulouse and FC Mulhouse(Idx=1765) are 0.631579 similar and from the same country France.
# Toulouse and Toulouse F.C.(Idx=4035) are 0.761905 similar and from the same country France.
# Toulouse and Toulouse FC(Idx=4036) are 0.842105 similar and from the same country France.
# Trabzonspor and 1461 Trabzon(Idx=55) are 0.608696 similar and from the same country Turkey.
# Trabzonspor and Trabzonspor(Idx=4039) are 1.000000 similar and from the same country Turkey.
# Trakia Plovdiv and FC Spartak Plovdiv(Idx=1852) are 0.687500 similar and from the same country Bulgaria.
# Twente and FC Twente(Idx=1886) are 0.800000 similar and from the same country Netherlands.
# UE Sant Julia and UE Sant Julià(Idx=4103) are 0.923077 similar and from the same country Andorra.
# UE Sant Julia and UE Santa Coloma(Idx=4104) are 0.714286 similar and from the same country Andorra.
# UT Arad and FC UTA Arad(Idx=1888) are 0.777778 similar and from the same country Romania.
# UT Arad and FC UTA Arad(Idx=1889) are 0.777778 similar and from the same country Romania.
# Ulisses and Ulisses FC(Idx=4132) are 0.823529 similar and from the same country Armenia.
# Unirea Urziceni and FC Unirea Urziceni(Idx=1892) are 0.909091 similar and from the same country Romania.
# Valencia CF and Algeciras CF(Idx=346) are 0.695652 similar and from the same country Spain.
# Valencia CF and Arandina CF(Idx=413) are 0.636364 similar and from the same country Spain.
# Valencia CF and CF Palencia(Idx=839) are 0.636364 similar and from the same country Spain.
# Valencia CF and Talavera CF(Idx=3966) are 0.636364 similar and from the same country Spain.
# Valencia CF and Valencia CF(Idx=4201) are 1.000000 similar and from the same country Spain.
# Valencia CF and Valencia CF Mestalla(Idx=4202) are 0.709677 similar and from the same country Spain.
# Valletta and Valletta F.C.(Idx=4206) are 0.761905 similar and from the same country Malta.
# Vaslui and FC Vaslui(Idx=1899) are 0.800000 similar and from the same country Romania.
# Vejle BK and Vejle Boldklub(Idx=4225) are 0.636364 similar and from the same country Denmark.
# VfB Stuttgart and VfB Stuttgart(Idx=4242) are 1.000000 similar and from the same country Germany.
# VfL Wolfsburg and VfB Oldenburg(Idx=4240) are 0.615385 similar and from the same country Germany.
# VfL Wolfsburg and VfL Wolfsburg(Idx=4248) are 1.000000 similar and from the same country Germany.
# VfL Wolfsburg and VfL Wolfsburg(Idx=4249) are 1.000000 similar and from the same country Germany.
# Videoton and Videoton FC(Idx=4263) are 0.842105 similar and from the same country Hungary.
# Viktoria Plzen and FC Viktoria Plzeň(Idx=1903) are 0.838710 similar and from the same country Czech Republic.
# Villarreal and CP Villarrobledo(Idx=850) are 0.615385 similar and from the same country Spain.
# Villarreal and Villarreal CF "B"(Idx=4272) are 0.740741 similar and from the same country Spain.
# Villarreal and Villarreal CF C(Idx=4273) are 0.800000 similar and from the same country Spain.
# Vojvodina and F.K. Vojvodina(Idx=1553) are 0.782609 similar and from the same country Serbia.
# Vorwarts Berlin and SV Tasmania Berlin(Idx=3606) are 0.606061 similar and from the same country Germany.
# WIT Georgia and FC WIT Georgia(Idx=1914) are 0.880000 similar and from the same country Georgia.
# Waterford AFC and Waterford United F.C.(Idx=4309) are 0.705882 similar and from the same country Ireland.
# Werder Bremen and SV Werder Bremen(Idx=3610) are 0.896552 similar and from the same country Germany.
# Werder Bremen and SV Werder Bremen II(Idx=3611) are 0.812500 similar and from the same country Germany.
# Widzew Lodz and Widzew Łódź(Idx=4331) are 0.727273 similar and from the same country Poland.
# Wiener Sport-Club and Vienna Sportclub(Idx=4264) are 0.727273 similar and from the same country Austria.
# Willem II and Willem II(Idx=4333) are 1.000000 similar and from the same country Netherlands.
# Wisla Krakow and Wisła Kraków(Idx=4336) are 0.833333 similar and from the same country Poland.
# Zaglebie Lubin and Zagłębie Lubin(Idx=4380) are 0.857143 similar and from the same country Poland.
# Zalaegerszegi TE and Zalaegerszegi TE(Idx=4381) are 1.000000 similar and from the same country Hungary.
# Zalgiris Vilnius and VMFD Žalgiris Vilnius(Idx=4192) are 0.810811 similar and from the same country Lithuania.
# Zbrojovka Brno and FC Zbrojovka Brno(Idx=1923) are 0.903226 similar and from the same country Czech Republic.
# Zeljeznicar Sarajevo and F.K. Željezničar Sarajevo(Idx=1554) are 0.800000 similar and from the same country Bosnia and Herzegovina.
# Zenit St. Petersburg and F.C. Zenit St. Petersburg(Idx=1549) are 0.888889 similar and from the same country Russia.
# Zenit St. Petersburg and FC Dynamo Saint Petersburg(Idx=1660) are 0.652174 similar and from the same country Russia.
# Zenit St. Petersburg and FC Petrotrest Saint Petersburg(Idx=1795) are 0.640000 similar and from the same country Russia.
# Zenit St. Petersburg and FC Rus Saint Petersburg(Idx=1817) are 0.651163 similar and from the same country Russia.
# Zestafoni and FC Zestafoni(Idx=1926) are 0.857143 similar and from the same country Georgia.
# Zulte-Waregem and S.V. Zulte Waregem(Idx=3510) are 0.774194 similar and from the same country Belgium.
# sc Heerenveen and SC Heerenveen(Idx=3522) are 0.846154 similar and from the same country Netherlands.
# CPU times: user 2min 7s, sys: 1.1 s, total: 2min 8s
# Wall time: 2min 8s
